# %%
import pandas as pd

# %% [markdown]
# ## Objective 1: Scrape data from openinsider.com. (pandas)
# - See assignment documentation for web scraping code ideas
# - Find out how to iterate through pages.
# - Aim for a year of data (50000 entries, estimated?)
# - Database Columns
#     - Filing Date
#     - Trade Date
#     - Ticker
#     - Company Name
#     - Industry
#     - Ins
#     - Trade Type (purchase or sell)
#     - Price
#     - Qty
#     - Owned
#     - %change in Owned
#     - Value earned or lost
#
#
# - Scraping
#     - Limits 1000 to a page, iterate through pages.
# - https://github.com/sd3v/openinsiderData
# - http://openinsider.com/latest-insider-trading
# - https://github.com/fonzelv/Data-Scarping-SEC-Form-4/blob/main/Scrape%20it%20in%20R
#
# - Combining
#     - Append subsequent pages to first page.

# %%
#test scrape first page of open insider, using week 8 instruction. Iterate using page at end of URL.
InsTrade1 = pd.read_html('http://openinsider.com/screener?s=&o=&pl=&ph=&ll=&lh=&fd=730&fdr=&td=0&tdr=&fdlyl=&fdlyh=&daysago=&xp=1&xs=1&vl=&vh=&ocl=&och=&sic1=-1&sicl=100&sich=9999&grp=0&nfl=&nfh=&nil=&nih=&nol=&noh=&v2l=&v2h=&oc2l=&oc2h=&sortcol=0&cnt=1000&page=2')

# %%
type(InsTrade1)
# Out:
# list

# %%
len(InsTrade1)
# Out:
# 14

# %% [markdown]
# Table 14 is the data we want.

# %%
InsTrade1[11].head()
# Out:
#      X          Filing Date  Trade Date Ticker  \
# 0    D  2023-11-07 15:38:13  2023-11-03   CVLY
# 1  NaN  2023-11-07 15:32:13  2023-11-02   NYCB
# 2  NaN  2023-11-07 15:22:40  2023-11-03   USNA
# 3  NaN  2023-11-07 15:07:45  2023-11-06    RBB
# 4  NaN  2023-11-07 15:01:51  2023-11-07   BRKL
#
#                      Company Name       Insider Name                    Title  \
# 0      Codorus Valley Bancorp Inc  Altland Stephen M       SVP of PeoplesBank
# 1  New York Community Bancorp Inc   Davis Reginald E  Sr EVP, Pres of Banking
# 2       Usana Health Sciences Inc   Fuller Gilbert A                      Dir
# 3                     Rbb Bancorp     Polakoff Scott                      Dir
# 4           Brookline Bancorp Inc     Hackett John A                      Dir
#
#      Trade Type   Price    Qty   Owned   ΔOwn      Value  1d  1w  1m  6m
# 0   S - Sale+OE  $19.86  -1676   17413    -9%   -$33,291 NaN NaN NaN NaN
# ...

# %% [markdown]
# ## Objective 2: use yahoo finance API to get stock data for a given date
# - See links for API code ideas
# - https://pypi.org/project/yahoo-finance/

# %%
-
# Out:
#   Cell In[35], line 1
#     -
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Objective 3: Determine/compare buy and sell
# - Compare and identify all buy and sell records in the database.
# - Differentiate the purchases that have a buy and sell record from those that just have a buy record.
# - Remove all records that only have a sell record (Buy record is before the first date in the database).

# %%
-
# Out:
#   Cell In[36], line 1
#     -
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Objective 4: Identify all insider trading regulations and limitations for project report.

# %% [markdown]
# -

# %% [markdown]
# ## Analysis Graph/Chart ideas (matplotlib):
# - Volume of trading by industry
# - Volume of trading by job title
# - Percentage of sell to buy over time periods
# - Profitability of trades
# - Yahoo finance API to find current value of holding
#     - If sell record, (sell price – buy price) * shares
#         - Find how to store name, job, value as variable and search in all newer entries.
#         - Store stock ticker as variable and use as function in API to iterate.
#     - If only a buy record: (current market stock price – buy price) * shares
# - Comparison of general market trend with dataset
# - Use Ape Wisdom site for comparison with individual investor sentiment

# %%
# Out:
#   Cell In[34], line 1
#     apewisdom = pd.read_html(http://apewisdom.io/api/v1.0/filter/all-stocks/page/4)
#                                  ^
# SyntaxError: invalid syntax
